# %% [markdown]
# ***This data set includes descriptions of hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family (pp. 500-525). Each species is identified as definitely edible, definitely poisonous, or of unknown edibility and not recommended. This latter class was combined with the poisonous one. The Guide clearly states that there is no simple rule for determining the edibility of a mushroom; no rule like ``leaflets three, let it be'' for Poisonous Oak and Ivy.***

# %% [markdown]
# ```
# 1. cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
# 2. cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
# 3. cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r, pink=p,purple=u,red=e,white=w,yellow=y
# 4. bruises?: bruises=t,no=f
# 5. odor: almond=a,anise=l,creosote=c,fishy=y,foul=f, musty=m,none=n,pungent=p,spicy=s
# 6. gill-attachment: attached=a,descending=d,free=f,notched=n
# 7. gill-spacing: close=c,crowded=w,distant=d
# 8. gill-size: broad=b,narrow=n
# 9. gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e, white=w,yellow=y
# 10. stalk-shape: enlarging=e,tapering=t
# 11. stalk-root: bulbous=b,club=c,cup=u,equal=e, rhizomorphs=z,rooted=r,missing=?
# 12. stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
# 13. stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
# 14. stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o, pink=p,red=e,white=w,yellow=y
# 15. stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o, pink=p,red=e,white=w,yellow=y
# 16. veil-type: partial=p,universal=u
# 17. veil-color: brown=n,orange=o,white=w,yellow=y
# 18. ring-number: none=n,one=o,two=t
# 19. ring-type: cobwebby=c,evanescent=e,flaring=f,large=l, none=n,pendant=p,sheathing=s,zone=z
# 20. spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r, orange=o,purple=u,white=w,yellow=y
# 21. population: abundant=a,clustered=c,numerous=n, scattered=s,several=v,solitary=y
# 22. habitat: grasses=g,leaves=l,meadows=m,paths=p, urban=u,waste=w,woods=d
# ```

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("mushrooms.csv")

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
df.drop(["veil-type"], axis=1, inplace=True)

# %% [markdown]
# ***Veil type contains only one unique value. So we can drop it***

# %%
df.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# ***There is no missing values (nan)***

# %%
# lets check the unique values
for i in df.columns:
    print(list(df[i].value_counts().index))
# Out:
# ['e', 'p']
# ['x', 'f', 'k', 'b', 's', 'c']
# ['y', 's', 'f', 'g']
# ['n', 'g', 'e', 'y', 'w', 'b', 'p', 'c', 'u', 'r']
# ['f', 't']
# ['n', 'f', 'y', 's', 'a', 'l', 'p', 'c', 'm']
# ['f', 'a']
# ['c', 'w']
# ['b', 'n']
# ['b', 'p', 'w', 'n', 'g', 'h', 'u', 'k', 'e', 'y', 'o', 'r']
# ['t', 'e']
# ['b', '?', 'e', 'c', 'r']
# ['s', 'k', 'f', 'y']
# ['s', 'k', 'f', 'y']
# ['w', 'p', 'g', 'n', 'b', 'o', 'e', 'c', 'y']
# ['w', 'p', 'g', 'n', 'b', 'o', 'e', 'c', 'y']
# ['w', 'n', 'o', 'y']
# ['o', 't', 'n']
# ['p', 'e', 'l', 'f', 'n']
# ['w', 'n', 'k', 'h', 'r', 'u', 'o', 'y', 'b']
# ['v', 'y', 's', 'n', 'a', 'c']
# ['d', 'g', 'p', 'l', 'u', 'm', 'w']

# %% [markdown]
# ***There is ? in the stalk-root. Data dictionary mentioned it as missing values***

# %%
df["stalk-root"].value_counts()
# Out:
# b    3776
# ?    2480
# e    1120
# c     556
# r     192
# Name: stalk-root, dtype: int64

# %% [markdown]
# ***!!! There was lot of data counted as ?. We have to find the right method either fill it with mode or dropping it. We can decide it only by verifying the accuracy of the both the approaches***

# %%
# lets check the duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
# lets check the value counts for target variableS
df["class"].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %% [markdown]
# ***Target variable is almost balanced***

# %% [markdown]
# ### Lets check count-plot for all the features

# %%
columns = df.columns

# %%
plt.suptitle('count plot for all features', 
             fontsize=20, 
             fontweight='bold', 
             alpha=0.8, 
             y=1.)

for i in range(0, len(columns)):
    ax = sns.countplot(x=df[columns[i]],palette="Set2") # Palette is color type
    plt.xlabel(columns[i], fontsize=16)
    plt.xticks(rotation=45, fontsize=16)
    ax.set_ylabel('Count', fontsize=16)
    plt.yticks(fontsize=16)
    plt.show()

# %% [markdown]
# ### Let's check the crosstab for all

# %%
for i in df.columns:
    if i != "class":
        crosstab_table = pd.crosstab(df[i], df['class'])
        print(crosstab_table)
        print("-"*50)
# Out:
# class         e     p
# cap-shape
# b           404    48
# c             0     4
# f          1596  1556
# k           228   600
# s            32     0
# x          1948  1708
# --------------------------------------------------
# class           e     p
# cap-surface
# f            1560   760
# g               0     4
# s            1144  1412
# y            1504  1740
# --------------------------------------------------
# class         e     p
# cap-color
# b            48   120
# c            32    12
# e           624   876
# g          1032   808
# n          1264  1020
# p            56    88
# r            16     0
# u            16     0
# w           720   320
# y           400   672
# --------------------------------------------------
# class       e     p
# bruises
# f        1456  3292
# t        2752   624
# --------------------------------------------------
# class     e     p
# odor
# a       400     0
# c         0   192
# f         0  2160
# l       400     0
# ...

# %% [markdown]
# ### Let's check chi-square test to test for independence between two categorical variables

# %%
import pandas as pd
from scipy.stats import chi2_contingency

for i in df.columns:
    contingency_table = pd.crosstab(df[i], df['class'])
    stat, p, dof, expected = chi2_contingency(contingency_table)
    print(f'Chi-square test: {i}')
    print('p-value:', p)
    print('-'*50)
# Out:
# Chi-square test: class
# p-value: 0.0
# --------------------------------------------------
# Chi-square test: cap-shape
# p-value: 1.196456568593578e-103
# --------------------------------------------------
# Chi-square test: cap-surface
# p-value: 5.518427038649143e-68
# --------------------------------------------------
# Chi-square test: cap-color
# p-value: 6.055814598336574e-78
# --------------------------------------------------
# Chi-square test: bruises
# p-value: 0.0
# --------------------------------------------------
# Chi-square test: odor
# p-value: 0.0
# --------------------------------------------------
# Chi-square test: gill-attachment
# p-value: 5.501707411861009e-31
# --------------------------------------------------
# Chi-square test: gill-spacing
# p-value: 5.022977613732478e-216
# --------------------------------------------------
# Chi-square test: gill-size
# p-value: 0.0
# --------------------------------------------------
# Chi-square test: gill-color
# ...

# %% [markdown]
# ***For all the variables listed, the p-value is less than 0.05. we usually reject the null hypothesis and conclude that there is a statistically significant relationship between the two categorical variables***
